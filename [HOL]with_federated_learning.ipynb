# %% [markdown]
# # Federated Learning을 사용하는 경우

# %%
import sys

print(sys.executable)
# Out:
# /home/sagemaker-user/.conda/envs/python311/bin/python

# %%
print(sys.version)
# Out:
# 3.11.14 | packaged by conda-forge | (main, Oct 22 2025, 22:46:25) [GCC 14.3.0]

# %%
# !{sys.executable} -V
# Out:
# Python 3.11.14

# %%
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: flwr==1.10.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (1.10.0)
# Requirement already satisfied: ray==2.6.3 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (2.6.3)
# Requirement already satisfied: flwr-datasets==0.2.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: torch==2.2.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (2.2.1)
# Requirement already satisfied: torchvision==0.17.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (0.17.1)
# Requirement already satisfied: matplotlib==3.8.3 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (3.8.3)
# Requirement already satisfied: scikit-learn==1.4.2 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (1.4.2)
# Requirement already satisfied: seaborn==0.13.2 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (0.13.2)
# Requirement already satisfied: ipywidgets==8.1.2 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (8.1.2)
# Requirement already satisfied: transformers==4.42.4 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (4.42.4)
# Requirement already satisfied: accelerate==0.30.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (0.30.0)
# Requirement already satisfied: cryptography<43.0.0,>=42.0.4 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (42.0.8)
# Requirement already satisfied: grpcio!=1.64.2,!=1.65.1,<2.0.0,>=1.60.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (1.76.0)
# Requirement already satisfied: iterators<0.0.3,>=0.0.2 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (0.0.2)
# Requirement already satisfied: numpy<2.0.0,>=1.21.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (1.26.4)
# Requirement already satisfied: pathspec<0.13.0,>=0.12.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: protobuf<5.0.0,>=4.25.2 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (4.25.8)
# Requirement already satisfied: pycryptodome<4.0.0,>=3.18.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (3.23.0)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: tomli-w<2.0.0,>=1.0.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from typer[all]<0.10.0,>=0.9.0->flwr==1.10.0->-r requirements.txt (line 5)) (0.9.4)
# Requirement already satisfied: click>=7.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (8.3.1)
# Requirement already satisfied: filelock in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (3.20.0)
# Requirement already satisfied: jsonschema in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (4.25.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (1.1.2)
# Requirement already satisfied: packaging in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (25.0)
# Requirement already satisfied: pyyaml in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (6.0.3)
# Requirement already satisfied: aiosignal in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: frozenlist in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: requests in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (2.32.5)
# Requirement already satisfied: datasets<2.20.0,>=2.14.6 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 10)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 10)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 10)) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 10)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from seaborn==0.13.2->-r requirements.txt (line 12)) (2.3.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: sympy in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (1.14.0)
# Requirement already satisfied: networkx in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (3.5)
# Requirement already satisfied: jinja2 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (3.1.6)
# Requirement already satisfied: fsspec in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (2.2.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from scikit-learn==1.4.2->-r requirements.txt (line 11)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from scikit-learn==1.4.2->-r requirements.txt (line 11)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from scikit-learn==1.4.2->-r requirements.txt (line 11)) (3.6.0)
# Requirement already satisfied: comm>=0.1.3 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ipywidgets==8.1.2->-r requirements.txt (line 13)) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ipywidgets==8.1.2->-r requirements.txt (line 13)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ipywidgets==8.1.2->-r requirements.txt (line 13)) (4.0.15)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ipywidgets==8.1.2->-r requirements.txt (line 13)) (3.0.16)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from transformers==4.42.4->-r requirements.txt (line 14)) (0.36.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from transformers==4.42.4->-r requirements.txt (line 14)) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from transformers==4.42.4->-r requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from transformers==4.42.4->-r requirements.txt (line 14)) (0.19.1)
# Requirement already satisfied: psutil in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from accelerate==0.30.0->-r requirements.txt (line 15)) (7.1.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1->-r requirements.txt (line 8)) (12.9.86)
# Requirement already satisfied: cffi>=1.12 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from cryptography<43.0.0,>=42.0.4->flwr==1.10.0->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (22.0.0)
# Requirement already satisfied: pyarrow-hotfix in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (0.7)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (0.3.8)
# Requirement already satisfied: xxhash in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: multiprocess in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (0.70.16)
# Requirement already satisfied: aiohttp in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (3.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.42.4->-r requirements.txt (line 14)) (1.2.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from typer[all]<0.10.0,>=0.9.0->flwr==1.10.0->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from typer[all]<0.10.0,>=0.9.0->flwr==1.10.0->-r requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from typer[all]<0.10.0,>=0.9.0->flwr==1.10.0->-r requirements.txt (line 5)) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->flwr==1.10.0->-r requirements.txt (line 5)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->flwr==1.10.0->-r requirements.txt (line 5)) (2.19.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (2.6.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (25.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (3.11)
# Requirement already satisfied: pycparser in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from cffi>=1.12->cryptography<43.0.0,>=42.0.4->flwr==1.10.0->-r requirements.txt (line 5)) (2.23)
# Requirement already satisfied: decorator>=4.3.2 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (3.0.52)
# Requirement already satisfied: stack_data>=0.6.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.6.3)
# Requirement already satisfied: wcwidth in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.8.5)
# Requirement already satisfied: mdurl~=0.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->flwr==1.10.0->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: pytz>=2020.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from pandas>=1.2->seaborn==0.13.2->-r requirements.txt (line 12)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from pandas>=1.2->seaborn==0.13.2->-r requirements.txt (line 12)) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib==3.8.3->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from requests->ray==2.6.3->-r requirements.txt (line 6)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from requests->ray==2.6.3->-r requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from requests->ray==2.6.3->-r requirements.txt (line 6)) (2025.11.12)
# Requirement already satisfied: executing>=1.2.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (3.0.1)
# Requirement already satisfied: pure_eval in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from jinja2->torch==2.2.1->-r requirements.txt (line 8)) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from jsonschema->ray==2.6.3->-r requirements.txt (line 6)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from jsonschema->ray==2.6.3->-r requirements.txt (line 6)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from jsonschema->ray==2.6.3->-r requirements.txt (line 6)) (0.29.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages (from sympy->torch==2.2.1->-r requirements.txt (line 8)) (1.3.0)

# %% [markdown]
# #### 1. Load imports

# %%
from flwr.client import Client, ClientApp, NumPyClient
from flwr.common import ndarrays_to_parameters, Context
from flwr.server import ServerApp, ServerConfig
from flwr.server import ServerAppComponents
from flwr.server.strategy import FedAvg
from flwr.simulation import run_simulation

from utils2 import *
# Out:
# /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# #### 2. Set up the training and testing datasets

# %% [markdown]
# * Set up the MNIST training datasets.

# %%
trainset = datasets.MNIST(
    "./MNIST_data/", download=True, train=True, transform=transform
)

total_length = len(trainset)
split_size = total_length // 3
torch.manual_seed(42)
part1, part2, part3 = random_split(trainset, [split_size] * 3)

part1 = exclude_digits(part1, excluded_digits=[1, 3, 7])
part2 = exclude_digits(part2, excluded_digits=[2, 5, 8])
part3 = exclude_digits(part3, excluded_digits=[4, 6, 9])

train_sets = [part1, part2, part3]

# %% [markdown]
# * Set up the MNIST testing datasets.

# %%
testset = datasets.MNIST(
    "./MNIST_data/", download=True, train=False, transform=transform
)
print("Number of examples in `testset`:", len(testset))

testset_137 = include_digits(testset, [1, 3, 7])
testset_258 = include_digits(testset, [2, 5, 8])
testset_469 = include_digits(testset, [4, 6, 9])
# Out:
# Number of examples in `testset`: 10000

# %% [markdown]
# #### 3. Define training and testing in the pipeline

# %% [markdown]
# * Set functions for the client-server exchange of the training information.

# %%
# Sets the parameters of the model
def set_weights(net, parameters):
    params_dict = zip(net.state_dict().keys(), parameters)
    state_dict = OrderedDict(
        {k: torch.tensor(v) for k, v in params_dict}
    )
    net.load_state_dict(state_dict, strict=True)

# Retrieves the parameters from the model
def get_weights(net):
    ndarrays = [
        val.cpu().numpy() for _, val in net.state_dict().items()
    ]
    return ndarrays

# %% [markdown]
# * Connect the training in the pipeline using the Flower Client.

# %%
class FlowerClient(NumPyClient):
    def __init__(self, net, trainset, testset):
        self.net = net
        self.trainset = trainset
        self.testset = testset

    # Train the model
    def fit(self, parameters, config):
        set_weights(self.net, parameters)
        train_model(self.net, self.trainset)
        return get_weights(self.net), len(self.trainset), {}

    # Test the model
    def evaluate(self, parameters: NDArrays, config: Dict[str, Scalar]):
        set_weights(self.net, parameters)
        loss, accuracy = evaluate_model(self.net, self.testset)
        return loss, len(self.testset), {"accuracy": accuracy}

# %% [markdown]
# * Flower calls `client_fn` whenever it needs an instance of one particular client to call fit or evaluate.

# %%
# Client function
def client_fn(context: Context) -> Client:
    net = SimpleModel()
    partition_id = int(context.node_config["partition-id"])
    client_train = train_sets[int(partition_id)]
    client_test = testset
    return FlowerClient(net, client_train, client_test).to_client()

# %% [markdown]
# * Create an instance of the ClientApp.

# %%
client = ClientApp(client_fn)

# %% [markdown]
# * Define `evaluate` for testing.
#
# The `evaluate` method evaluates the performance of the neural network model using the provided parameters and the test dataset (`testset`).

# %%
def evaluate(server_round, parameters, config):
    net = SimpleModel()
    set_weights(net, parameters)

    _, accuracy = evaluate_model(net, testset)
    _, accuracy137 = evaluate_model(net, testset_137)
    _, accuracy258 = evaluate_model(net, testset_258)
    _, accuracy469 = evaluate_model(net, testset_469)

    log(INFO, "test accuracy on all digits: %.4f", accuracy)
    log(INFO, "test accuracy on [1,3,7]: %.4f", accuracy137)
    log(INFO, "test accuracy on [2,5,8]: %.4f", accuracy258)
    log(INFO, "test accuracy on [4,6,9]: %.4f", accuracy469)

    if server_round == 3:
        cm = compute_confusion_matrix(net, testset)
        plot_confusion_matrix(cm, "Final Global Model")

# %% [markdown]
# * Strategy: Federated Average 'FedAvg'.
#
# The federated averaging strategy (`strategy.FedAvg`) is created for federated learning.

# %%
net = SimpleModel()
params = ndarrays_to_parameters(get_weights(net))

def server_fn(context: Context):
    strategy = FedAvg(
        fraction_fit=1.0,
        fraction_evaluate=0.0,
        initial_parameters=params,
        evaluate_fn=evaluate,
    )
    config=ServerConfig(num_rounds=3)
    return ServerAppComponents(
        strategy=strategy,
        config=config,
    )

# %% [markdown]
# * Create an instance of ServerApp.

# %%
server = ServerApp(server_fn=server_fn)

# %% [markdown]
# * Start training.

# %%
# Initiate the simulation passing the server and client apps
# Specify the number of super nodes that will be selected on every round
run_simulation(
    server_app=server,
    client_app=client,
    num_supernodes=3,
    backend_config=backend_setup,
)
# Out:
# INFO :      Starting Flower ServerApp, config: num_rounds=3, no round_timeout
# INFO :
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Evaluating initial global parameters
# INFO :      test accuracy on all digits: 0.1267
# INFO :      test accuracy on [1,3,7]: 0.2275
# INFO :      test accuracy on [2,5,8]: 0.1201
# INFO :      test accuracy on [4,6,9]: 0.0380
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      test accuracy on all digits: 0.8586
# INFO :      test accuracy on [1,3,7]: 0.9411
# INFO :      test accuracy on [2,5,8]: 0.7605
# INFO :      test accuracy on [4,6,9]: 0.8199
# INFO :      configure_evaluate: no clients selected, skipping evaluation
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      test accuracy on all digits: 0.9514
# INFO :      test accuracy on [1,3,7]: 0.9663
# INFO :      test accuracy on [2,5,8]: 0.9320
# INFO :      test accuracy on [4,6,9]: 0.9393
# INFO :      configure_evaluate: no clients selected, skipping evaluation
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      test accuracy on all digits: 0.9606
# INFO :      test accuracy on [1,3,7]: 0.9760
# INFO :      test accuracy on [2,5,8]: 0.9410
# INFO :      test accuracy on [4,6,9]: 0.9515
# /home/sagemaker-user/.conda/envs/python311/lib/python3.11/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
# INFO :      configure_evaluate: no clients selected, skipping evaluation
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 3 round(s) in 111.69s
# INFO :
