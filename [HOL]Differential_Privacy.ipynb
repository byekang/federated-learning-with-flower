# %% [markdown]
# # Differential Privacy를 이용한 연합 학습

# %% [markdown]
# #### 1. Load imports

# %%
import sys

print(sys.executable)
# Out:
# /home/ec2-user/anaconda3/envs/python3/bin/python

# %%
print(sys.version)
# Out:
# 3.10.17 | packaged by conda-forge | (main, Apr 10 2025, 22:19:12) [GCC 13.3.0]

# %%
print(sys.version)
# Out:
# 3.10.17 | packaged by conda-forge | (main, Apr 10 2025, 22:19:12) [GCC 13.3.0]

# %%
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# WARNING: Ignoring invalid distribution -ransformers (/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages)
# Requirement already satisfied: flwr==1.10.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.10.0)
# Requirement already satisfied: ray==2.6.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (2.6.3)
# Requirement already satisfied: flwr-datasets==0.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: torch==2.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (2.2.1)
# Requirement already satisfied: torchvision==0.17.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (0.17.1)
# Requirement already satisfied: matplotlib==3.8.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (3.8.3)
# Requirement already satisfied: scikit-learn==1.4.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (1.4.2)
# Requirement already satisfied: seaborn==0.13.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (0.13.2)
# Requirement already satisfied: ipywidgets==8.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (8.1.2)
# Requirement already satisfied: transformers==4.42.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (4.42.4)
# Requirement already satisfied: accelerate==0.30.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (0.30.0)
# Requirement already satisfied: cryptography<43.0.0,>=42.0.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (42.0.7)
# Requirement already satisfied: grpcio!=1.64.2,!=1.65.1,<2.0.0,>=1.60.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (1.72.1)
# Requirement already satisfied: iterators<0.0.3,>=0.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (0.0.2)
# Requirement already satisfied: numpy<2.0.0,>=1.21.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (1.26.4)
# Requirement already satisfied: pathspec<0.13.0,>=0.12.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: protobuf<5.0.0,>=4.25.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (4.25.8)
# Requirement already satisfied: pycryptodome<4.0.0,>=3.18.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (3.22.0)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (2.2.1)
# Requirement already satisfied: tomli-w<2.0.0,>=1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flwr==1.10.0->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from typer[all]<0.10.0,>=0.9.0->flwr==1.10.0->-r requirements.txt (line 5)) (0.9.4)
# Requirement already satisfied: click>=7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (8.1.8)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (3.16.1)
# Requirement already satisfied: jsonschema in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pyyaml in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: aiosignal in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: frozenlist in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ray==2.6.3->-r requirements.txt (line 6)) (2.32.3)
# Requirement already satisfied: datasets<2.20.0,>=2.14.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 10)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 10)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 10)) (1.4.7)
# Requirement already satisfied: pillow>=8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 10)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 10)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib==3.8.3->-r requirements.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from seaborn==0.13.2->-r requirements.txt (line 12)) (2.3.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (1.13.1)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (3.4)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (3.1.6)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.2.1->-r requirements.txt (line 8)) (2.2.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn==1.4.2->-r requirements.txt (line 11)) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn==1.4.2->-r requirements.txt (line 11)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn==1.4.2->-r requirements.txt (line 11)) (3.6.0)
# Requirement already satisfied: comm>=0.1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipywidgets==8.1.2->-r requirements.txt (line 13)) (8.35.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipywidgets==8.1.2->-r requirements.txt (line 13)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipywidgets==8.1.2->-r requirements.txt (line 13)) (4.0.14)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipywidgets==8.1.2->-r requirements.txt (line 13)) (3.0.14)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from transformers==4.42.4->-r requirements.txt (line 14)) (0.36.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from transformers==4.42.4->-r requirements.txt (line 14)) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from transformers==4.42.4->-r requirements.txt (line 14)) (0.5.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from transformers==4.42.4->-r requirements.txt (line 14)) (0.19.1)
# Requirement already satisfied: psutil in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from accelerate==0.30.0->-r requirements.txt (line 15)) (6.1.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1->-r requirements.txt (line 8)) (12.4.127)
# Requirement already satisfied: cffi>=1.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from cryptography<43.0.0,>=42.0.4->flwr==1.10.0->-r requirements.txt (line 5)) (1.17.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (14.0.0)
# Requirement already satisfied: pyarrow-hotfix in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (0.3.8)
# Requirement already satisfied: xxhash in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (3.5.0)
# Requirement already satisfied: multiprocess in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (0.70.16)
# Requirement already satisfied: aiohttp in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (3.11.18)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.42.4->-r requirements.txt (line 14)) (1.1.3)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from typer[all]<0.10.0,>=0.9.0->flwr==1.10.0->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from typer[all]<0.10.0,>=0.9.0->flwr==1.10.0->-r requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from typer[all]<0.10.0,>=0.9.0->flwr==1.10.0->-r requirements.txt (line 5)) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->flwr==1.10.0->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->flwr==1.10.0->-r requirements.txt (line 5)) (2.19.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (2.6.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (1.20.0)
# Requirement already satisfied: idna>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets<2.20.0,>=2.14.6->flwr-datasets==0.2.0->flwr-datasets[vision]==0.2.0->-r requirements.txt (line 7)) (3.10)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from cffi>=1.12->cryptography<43.0.0,>=42.0.4->flwr==1.10.0->-r requirements.txt (line 5)) (2.22)
# Requirement already satisfied: decorator in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (5.2.1)
# Requirement already satisfied: exceptiongroup in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (3.0.51)
# Requirement already satisfied: stack_data in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.6.3)
# Requirement already satisfied: wcwidth in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->flwr==1.10.0->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas>=1.2->seaborn==0.13.2->-r requirements.txt (line 12)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas>=1.2->seaborn==0.13.2->-r requirements.txt (line 12)) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.8.3->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->ray==2.6.3->-r requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->ray==2.6.3->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->ray==2.6.3->-r requirements.txt (line 6)) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jinja2->torch==2.2.1->-r requirements.txt (line 8)) (2.1.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->ray==2.6.3->-r requirements.txt (line 6)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->ray==2.6.3->-r requirements.txt (line 6)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->ray==2.6.3->-r requirements.txt (line 6)) (0.24.0)
# Requirement already satisfied: executing>=1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (3.0.0)
# Requirement already satisfied: pure_eval in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.1.2->-r requirements.txt (line 13)) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sympy->torch==2.2.1->-r requirements.txt (line 8)) (1.3.0)
# WARNING: Ignoring invalid distribution -ransformers (/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ransformers (/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages)

# %% [markdown]
# 필요한 패키지를 import 합니다.

# %%
from flwr.client.mod import adaptiveclipping_mod
from flwr.server.strategy import (
    DifferentialPrivacyClientSideAdaptiveClipping,
    FedAvg,
)

from utils4 import *
# Out:
# 2025-11-26 02:18:18.914691: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764123499.120568    7984 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764123499.184139    7984 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764123499.713049    7984 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764123499.713077    7984 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764123499.713079    7984 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764123499.713081    7984 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-26 02:18:19.771208: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# #### 2. Load the MNIST dataset

# %% [markdown]
# * 연합 학습을 경험할 수 있는 `flwr-datasets` 데이터셋을 이용합니다.

# %%
def load_data(partition_id):
    fds = FederatedDataset(dataset="mnist", partitioners={"train": 10})
    partition = fds.load_partition(partition_id)

    traintest = partition.train_test_split(test_size=0.2, seed=42)
    traintest = traintest.with_transform(normalize)
    trainset, testset = traintest["train"], traintest["test"]

    trainloader = DataLoader(trainset, batch_size=64, shuffle=True)
    testloader = DataLoader(testset, batch_size=64)
    return trainloader, testloader

# %% [markdown]
# #### 3. Define the Model

# %% [markdown]
# * FlowerClient를 정의합니다.

# %%
class FlowerClient(NumPyClient):
    def __init__(self, net, trainloader, testloader):
        self.net = net
        self.trainloader = trainloader
        self.testloader = testloader

    def fit(self, parameters, config):
        set_weights(self.net, parameters)
        train_model(self.net, self.trainloader)
        return get_weights(self.net), len(self.trainloader), {}

    def evaluate(self, parameters, config):
        set_weights(self.net, parameters)
        loss, accuracy = evaluate_model(self.net, self.testloader)
        return loss, len(self.testloader), {"accuracy": accuracy}


def client_fn(context: Context) -> Client:
    net = SimpleModel()
    partition_id = int(context.node_config["partition-id"])
    trainloader, testloader = load_data(partition_id=partition_id)
    return FlowerClient(net, trainloader, testloader).to_client()

# %% [markdown]
# * ClientApp을 정의합니다.

# %% [markdown]
# 특히, `mods=[adaptiveclipping_mod]` 는 아래와 같은 역할을 수행합니다.
#
# 1. 클라이언트의 gradient 또는 weight update를 받아
# 2. norm을 측정한 뒤
# 3. gradient clipping threshold(C)를 동적으로(adaptive) 조절하고
# 4. clip된 업데이트만 서버로 반환

# %%
client = ClientApp(
    client_fn,
    mods=[adaptiveclipping_mod],  # modifiers
)

# %% [markdown]
# * 서버에서도 Server DP에 대한 전략이 적용되도록 `FedAvg` 부분을 수정합니다.
#
# **DP:** Differential Privacy.

# %%
net = SimpleModel()
params = ndarrays_to_parameters(get_weights(net))

def server_fn(context: Context):
    fedavg_without_dp = FedAvg(
        fraction_fit=0.6,
        fraction_evaluate=1.0,
        initial_parameters=params,
    )
    fedavg_with_dp = DifferentialPrivacyClientSideAdaptiveClipping(
        fedavg_without_dp,  # <- wrap the FedAvg strategy
        noise_multiplier=0.3,
        num_sampled_clients=6,
    )
    
    # Adjust to 50 rounds to ensure DP guarantees hold
    # with respect to the desired privacy budget
    config = ServerConfig(num_rounds=5)
    
    return ServerAppComponents(
        strategy=fedavg_with_dp,
        config=config,
    )

# %%
server = ServerApp(server_fn=server_fn)

# %% [markdown]
# * 아래 구문을 이용해서 연합 학습을 수행합니다.

# %%
run_simulation(server_app=server,
               client_app=client,
               num_supernodes=10,
               backend_config=backend_setup
               )
# Out:
# INFO : Starting Flower ServerApp, config: num_rounds=5, no round_timeout
# INFO :
# INFO : [INIT]
# INFO : Using initial global parameters provided by strategy
# INFO : Evaluating initial global parameters
# INFO :
# INFO : [ROUND 1]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (raylet) /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ray/_private/parameter.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (raylet)   import pkg_resources
# (pid=9011) 2025-11-26 02:18:41.211078: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=9011) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (pid=9011) E0000 00:00:1764123521.229779    9011 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=9011) E0000 00:00:1764123521.235414    9011 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=9011) W0000 00:00:1764123521.249536    9011 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (pid=9011) W0000 00:00:1764123521.249565    9011 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (pid=9011) W0000 00:00:1764123521.249568    9011 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (pid=9011) W0000 00:00:1764123521.249570    9011 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (pid=9011) 2025-11-26 02:18:41.253865: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# (pid=9011) To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Downloading readme: 6.97kB [00:00, 3.67MB/s]
# (pid=9012) 2025-11-26 02:18:41.395105: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (pid=9012) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR [repeated 7x across cluster]
# (pid=9012) E0000 00:00:1764123521.414051    9012 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered [repeated 7x across cluster]
# (pid=9012) E0000 00:00:1764123521.419689    9012 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered [repeated 7x across cluster]
# (pid=9012) W0000 00:00:1764123521.433900    9012 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once. [repeated 28x across cluster]
# (pid=9012) 2025-11-26 02:18:41.438252: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations. [repeated 7x across cluster]
# (pid=9012) To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags. [repeated 7x across cluster]
# (ClientAppActor pid=9013) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.1000.
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0052 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 2]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=9011) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0901. [repeated 6x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0047 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 3]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0042 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 4]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=9008) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0719. [repeated 12x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0037 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 5]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0034 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [SUMMARY]
# INFO : Run finished 5 round(s) in 36.90s
# INFO : 	History (loss, distributed):
# INFO : 		round 1: 43.03067536354065
# INFO : 		round 2: 41.89121503829956
# INFO : 		round 3: 40.98663306236267
# INFO : 		round 4: 39.971109890937804
# INFO : 		round 5: 39.35333563089371
# INFO :
# (ClientAppActor pid=9008) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0646. [repeated 11x across cluster]
