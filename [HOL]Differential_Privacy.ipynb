# %% [markdown]
# # Differential Privacy를 이용한 연합 학습

# %% [markdown]
# #### 1. Load imports

# %%
import sys

print(sys.executable)
# Out:
# /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/bin/python

# %%
print(sys.version)
# Out:
# 3.12.3 (main, Mar 23 2026, 19:04:32) [GCC 13.3.0]

# %%
print(sys.version)
# Out:
# 3.12.3 (main, Mar 23 2026, 19:04:32) [GCC 13.3.0]

# %%
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: flwr==1.13.1 in ./.venv/lib/python3.12/site-packages (from flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (1.13.1)
# Requirement already satisfied: flwr-datasets==0.5.0 in ./.venv/lib/python3.12/site-packages (from flwr-datasets[vision]==0.5.0->-r requirements.txt (line 6)) (0.5.0)
# Requirement already satisfied: ray==2.31.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (2.31.0)
# Requirement already satisfied: torch==2.4.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (2.4.1)
# Requirement already satisfied: torchvision==0.19.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (0.19.1)
# Requirement already satisfied: matplotlib==3.9.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (3.9.2)
# Requirement already satisfied: scikit-learn==1.5.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (1.5.2)
# Requirement already satisfied: seaborn==0.13.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (0.13.2)
# Requirement already satisfied: ipywidgets==8.1.5 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (8.1.5)
# Requirement already satisfied: transformers==4.45.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (4.45.2)
# Requirement already satisfied: accelerate==1.0.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (1.0.1)
# Requirement already satisfied: numpy<2.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (1.26.4)
# Requirement already satisfied: jupyter==1.1.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (1.1.1)
# Requirement already satisfied: ipykernel==6.29.5 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (6.29.5)
# Requirement already satisfied: cryptography<43.0.0,>=42.0.4 in ./.venv/lib/python3.12/site-packages (from flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (42.0.8)
# Requirement already satisfied: grpcio!=1.64.2,<2.0.0,<=1.64.3,>=1.60.0 in ./.venv/lib/python3.12/site-packages (from flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (1.64.3)
# Requirement already satisfied: iterators<0.0.3,>=0.0.2 in ./.venv/lib/python3.12/site-packages (from flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (0.0.2)
# Requirement already satisfied: pathspec<0.13.0,>=0.12.1 in ./.venv/lib/python3.12/site-packages (from flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: protobuf<5.0.0,>=4.25.2 in ./.venv/lib/python3.12/site-packages (from flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (4.25.9)
# Requirement already satisfied: pycryptodome<4.0.0,>=3.18.0 in ./.venv/lib/python3.12/site-packages (from flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (3.23.0)
# Requirement already satisfied: rich<14.0.0,>=13.5.0 in ./.venv/lib/python3.12/site-packages (from flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (13.9.4)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in ./.venv/lib/python3.12/site-packages (from flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (2.4.1)
# Requirement already satisfied: tomli-w<2.0.0,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: typer<0.13.0,>=0.12.5 in ./.venv/lib/python3.12/site-packages (from flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (0.12.5)
# Requirement already satisfied: datasets<=3.1.0,>=2.14.6 in ./.venv/lib/python3.12/site-packages (from flwr-datasets==0.5.0->flwr-datasets[vision]==0.5.0->-r requirements.txt (line 6)) (3.1.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./.venv/lib/python3.12/site-packages (from flwr-datasets==0.5.0->flwr-datasets[vision]==0.5.0->-r requirements.txt (line 6)) (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 10)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 10)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 10)) (26.2)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 10)) (12.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in ./.venv/lib/python3.12/site-packages (from seaborn==0.13.2->-r requirements.txt (line 12)) (3.0.3)
# Requirement already satisfied: click>=7.0 in ./.venv/lib/python3.12/site-packages (from ray==2.31.0->-r requirements.txt (line 7)) (8.4.1)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from ray==2.31.0->-r requirements.txt (line 7)) (3.29.0)
# Requirement already satisfied: jsonschema in ./.venv/lib/python3.12/site-packages (from ray==2.31.0->-r requirements.txt (line 7)) (4.26.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from ray==2.31.0->-r requirements.txt (line 7)) (1.1.2)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.12/site-packages (from ray==2.31.0->-r requirements.txt (line 7)) (6.0.3)
# Requirement already satisfied: aiosignal in ./.venv/lib/python3.12/site-packages (from ray==2.31.0->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: frozenlist in ./.venv/lib/python3.12/site-packages (from ray==2.31.0->-r requirements.txt (line 7)) (1.8.0)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from ray==2.31.0->-r requirements.txt (line 7)) (2.34.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: sympy in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (1.14.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (3.6.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (3.1.6)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (2024.9.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (82.0.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in ./.venv/lib/python3.12/site-packages (from torch==2.4.1->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: scipy>=1.6.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn==1.5.2->-r requirements.txt (line 11)) (1.17.1)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn==1.5.2->-r requirements.txt (line 11)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn==1.5.2->-r requirements.txt (line 11)) (3.6.0)
# Requirement already satisfied: comm>=0.1.3 in ./.venv/lib/python3.12/site-packages (from ipywidgets==8.1.5->-r requirements.txt (line 13)) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in ./.venv/lib/python3.12/site-packages (from ipywidgets==8.1.5->-r requirements.txt (line 13)) (9.13.0)
# Requirement already satisfied: traitlets>=4.3.1 in ./.venv/lib/python3.12/site-packages (from ipywidgets==8.1.5->-r requirements.txt (line 13)) (5.15.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in ./.venv/lib/python3.12/site-packages (from ipywidgets==8.1.5->-r requirements.txt (line 13)) (4.0.15)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in ./.venv/lib/python3.12/site-packages (from ipywidgets==8.1.5->-r requirements.txt (line 13)) (3.0.16)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in ./.venv/lib/python3.12/site-packages (from transformers==4.45.2->-r requirements.txt (line 14)) (0.36.2)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.12/site-packages (from transformers==4.45.2->-r requirements.txt (line 14)) (2026.5.9)
# Requirement already satisfied: safetensors>=0.4.1 in ./.venv/lib/python3.12/site-packages (from transformers==4.45.2->-r requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in ./.venv/lib/python3.12/site-packages (from transformers==4.45.2->-r requirements.txt (line 14)) (0.20.3)
# Requirement already satisfied: psutil in ./.venv/lib/python3.12/site-packages (from accelerate==1.0.1->-r requirements.txt (line 15)) (7.2.2)
# Requirement already satisfied: notebook in ./.venv/lib/python3.12/site-packages (from jupyter==1.1.1->-r requirements.txt (line 17)) (7.5.6)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.12/site-packages (from jupyter==1.1.1->-r requirements.txt (line 17)) (6.6.3)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.12/site-packages (from jupyter==1.1.1->-r requirements.txt (line 17)) (7.17.1)
# Requirement already satisfied: jupyterlab in ./.venv/lib/python3.12/site-packages (from jupyter==1.1.1->-r requirements.txt (line 17)) (4.5.7)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.12/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 18)) (1.8.20)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.12/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 18)) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.12/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 18)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.12/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 18)) (0.2.2)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.12/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 18)) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in ./.venv/lib/python3.12/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 18)) (27.1.0)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.12/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 18)) (6.5.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.venv/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.1->-r requirements.txt (line 8)) (12.9.86)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.12/site-packages (from cryptography<43.0.0,>=42.0.4->flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: pyarrow>=15.0.0 in ./.venv/lib/python3.12/site-packages (from datasets<=3.1.0,>=2.14.6->flwr-datasets==0.5.0->flwr-datasets[vision]==0.5.0->-r requirements.txt (line 6)) (24.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in ./.venv/lib/python3.12/site-packages (from datasets<=3.1.0,>=2.14.6->flwr-datasets==0.5.0->flwr-datasets[vision]==0.5.0->-r requirements.txt (line 6)) (0.3.8)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.12/site-packages (from datasets<=3.1.0,>=2.14.6->flwr-datasets==0.5.0->flwr-datasets[vision]==0.5.0->-r requirements.txt (line 6)) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.17 in ./.venv/lib/python3.12/site-packages (from datasets<=3.1.0,>=2.14.6->flwr-datasets==0.5.0->flwr-datasets[vision]==0.5.0->-r requirements.txt (line 6)) (0.70.16)
# Requirement already satisfied: aiohttp in ./.venv/lib/python3.12/site-packages (from datasets<=3.1.0,>=2.14.6->flwr-datasets==0.5.0->flwr-datasets[vision]==0.5.0->-r requirements.txt (line 6)) (3.13.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.2->-r requirements.txt (line 14)) (1.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich<14.0.0,>=13.5.0->flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich<14.0.0,>=13.5.0->flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (2.20.0)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.12/site-packages (from typer<0.13.0,>=0.12.5->flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->datasets<=3.1.0,>=2.14.6->flwr-datasets==0.5.0->flwr-datasets[vision]==0.5.0->-r requirements.txt (line 6)) (2.6.2)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->datasets<=3.1.0,>=2.14.6->flwr-datasets==0.5.0->flwr-datasets[vision]==0.5.0->-r requirements.txt (line 6)) (26.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp->datasets<=3.1.0,>=2.14.6->flwr-datasets==0.5.0->flwr-datasets[vision]==0.5.0->-r requirements.txt (line 6)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->datasets<=3.1.0,>=2.14.6->flwr-datasets==0.5.0->flwr-datasets[vision]==0.5.0->-r requirements.txt (line 6)) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->datasets<=3.1.0,>=2.14.6->flwr-datasets==0.5.0->flwr-datasets[vision]==0.5.0->-r requirements.txt (line 6)) (1.24.2)
# Requirement already satisfied: idna>=2.0 in ./.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets<=3.1.0,>=2.14.6->flwr-datasets==0.5.0->flwr-datasets[vision]==0.5.0->-r requirements.txt (line 6)) (3.16)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.12/site-packages (from cffi>=1.12->cryptography<43.0.0,>=42.0.4->flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (3.0)
# Requirement already satisfied: decorator>=5.1.0 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r requirements.txt (line 13)) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r requirements.txt (line 13)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r requirements.txt (line 13)) (0.20.0)
# Requirement already satisfied: pexpect>4.6 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r requirements.txt (line 13)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r requirements.txt (line 13)) (3.0.52)
# Requirement already satisfied: stack_data>=0.6.0 in ./.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.5->-r requirements.txt (line 13)) (0.6.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets==8.1.5->-r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in ./.venv/lib/python3.12/site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets==8.1.5->-r requirements.txt (line 13)) (0.8.7)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.29.5->-r requirements.txt (line 18)) (4.9.6)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.5.0->flwr==1.13.1->flwr[simulation]==1.13.1->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.12/site-packages (from pexpect>4.6->ipython>=6.1.0->ipywidgets==8.1.5->-r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib==3.9.2->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->ray==2.31.0->-r requirements.txt (line 7)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv/lib/python3.12/site-packages (from requests->ray==2.31.0->-r requirements.txt (line 7)) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./.venv/lib/python3.12/site-packages (from requests->ray==2.31.0->-r requirements.txt (line 7)) (2026.5.20)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets==8.1.5->-r requirements.txt (line 13)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets==8.1.5->-r requirements.txt (line 13)) (3.0.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets==8.1.5->-r requirements.txt (line 13)) (0.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2->torch==2.4.1->-r requirements.txt (line 8)) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.12/site-packages (from jsonschema->ray==2.31.0->-r requirements.txt (line 7)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.12/site-packages (from jsonschema->ray==2.31.0->-r requirements.txt (line 7)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in ./.venv/lib/python3.12/site-packages (from jsonschema->ray==2.31.0->-r requirements.txt (line 7)) (0.30.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (2.18.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in ./.venv/lib/python3.12/site-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (0.2.4)
# Requirement already satisfied: anyio in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (4.13.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (0.14.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (25.1.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (4.1.0)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (0.1.1)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (1.1.0)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.12/site-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 17)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in ./.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r requirements.txt (line 17)) (6.3.0)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.12/site-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 17)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.12/site-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 17)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.12/site-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 17)) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.12/site-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 17)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.12/site-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r requirements.txt (line 17)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in ./.venv/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (1.3.1)
# Requirement already satisfied: soupsieve>=1.6.1 in ./.venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter==1.1.1->-r requirements.txt (line 17)) (2.8.4)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: tzdata in ./.venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 17)) (2026.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from sympy->torch==2.4.1->-r requirements.txt (line 8)) (1.3.0)

# %% [markdown]
# 필요한 패키지를 import 합니다.

# %%
from flwr.client.mod import adaptiveclipping_mod
from flwr.server.strategy import (
    DifferentialPrivacyClientSideAdaptiveClipping,
    FedAvg,
)

from utils4 import *
# Out:
# /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_mathtext.py:45: PyparsingDeprecationWarning: 'enablePackrat' deprecated - use 'enable_packrat'
#   ParserElement.enablePackrat()
# In /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'parseString' deprecated - use 'parse_string'
# In /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'resetCache' deprecated - use 'reset_cache'

# %% [markdown]
# #### 2. Load the MNIST dataset

# %% [markdown]
# * 연합 학습을 경험할 수 있는 `flwr-datasets` 데이터셋을 이용합니다.

# %%
def load_data(partition_id):
    fds = FederatedDataset(dataset="mnist", partitioners={"train": 10})
    partition = fds.load_partition(partition_id)

    traintest = partition.train_test_split(test_size=0.2, seed=42)
    traintest = traintest.with_transform(normalize)
    trainset, testset = traintest["train"], traintest["test"]

    trainloader = DataLoader(trainset, batch_size=64, shuffle=True)
    testloader = DataLoader(testset, batch_size=64)
    return trainloader, testloader

# %% [markdown]
# #### 3. Define the Model

# %% [markdown]
# * FlowerClient를 정의합니다.

# %%
class FlowerClient(NumPyClient):
    def __init__(self, net, trainloader, testloader):
        self.net = net
        self.trainloader = trainloader
        self.testloader = testloader

    def fit(self, parameters, config):
        set_weights(self.net, parameters)
        train_model(self.net, self.trainloader)
        return get_weights(self.net), len(self.trainloader), {}

    def evaluate(self, parameters, config):
        set_weights(self.net, parameters)
        loss, accuracy = evaluate_model(self.net, self.testloader)
        return loss, len(self.testloader), {"accuracy": accuracy}


def client_fn(context: Context) -> Client:
    net = SimpleModel()
    partition_id = int(context.node_config["partition-id"])
    trainloader, testloader = load_data(partition_id=partition_id)
    return FlowerClient(net, trainloader, testloader).to_client()

# %% [markdown]
# * ClientApp을 정의합니다.

# %% [markdown]
# 특히, `mods=[adaptiveclipping_mod]` 는 아래와 같은 역할을 수행합니다.
#
# 1. 클라이언트의 gradient 또는 weight update를 받아
# 2. norm을 측정한 뒤
# 3. gradient clipping threshold(C)를 동적으로(adaptive) 조절하고
# 4. clip된 업데이트만 서버로 반환

# %%
client = ClientApp(
    client_fn,
    mods=[adaptiveclipping_mod],  # modifiers
)

# %% [markdown]
# * 서버에서도 Server DP에 대한 전략이 적용되도록 `FedAvg` 부분을 수정합니다.
#
# **DP:** Differential Privacy.

# %%
net = SimpleModel()
params = ndarrays_to_parameters(get_weights(net))

def server_fn(context: Context):
    fedavg_without_dp = FedAvg(
        fraction_fit=0.6,
        fraction_evaluate=1.0,
        initial_parameters=params,
    )
    fedavg_with_dp = DifferentialPrivacyClientSideAdaptiveClipping(
        fedavg_without_dp,  # <- wrap the FedAvg strategy
        noise_multiplier=0.3,
        num_sampled_clients=6,
    )
    
    # Adjust to 50 rounds to ensure DP guarantees hold
    # with respect to the desired privacy budget
    config = ServerConfig(num_rounds=5)
    
    return ServerAppComponents(
        strategy=fedavg_with_dp,
        config=config,
    )

# %%
server = ServerApp(server_fn=server_fn)

# %% [markdown]
# * 아래 구문을 이용해서 연합 학습을 수행합니다.

# %%
run_simulation(server_app=server,
               client_app=client,
               num_supernodes=10,
               backend_config=backend_setup
               )
# Out:
# INFO : Starting Flower ServerApp, config: num_rounds=5, no round_timeout
# INFO :
# INFO : [INIT]
# INFO : Using initial global parameters provided by strategy
# INFO : Starting evaluation of initial global parameters
# INFO : Evaluation returned no results (`None`)
# INFO :
# INFO : [ROUND 1]
# INFO : configure_fit: strategy sampled 2 clients (out of 10)
# (ClientAppActor pid=56990) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
# (ClientAppActor pid=56990)   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# (ClientAppActor pid=56990) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
# (ClientAppActor pid=56990)   parse = parser.parseString(pattern)
# (ClientAppActor pid=56990) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
# (ClientAppActor pid=56990)   parser.resetCache()
# (ClientAppActor pid=56990) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_mathtext.py:45: PyparsingDeprecationWarning: 'enablePackrat' deprecated - use 'enable_packrat'
# (ClientAppActor pid=56990)   ParserElement.enablePackrat()
# (ClientAppActor pid=56990) In /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'parseString' deprecated - use 'parse_string'
# (ClientAppActor pid=56990) In /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'resetCache' deprecated - use 'reset_cache'
# (ClientAppActor pid=56990) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.1000.
# (ClientAppActor pid=56989) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
# (ClientAppActor pid=56989)   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# (ClientAppActor pid=56989) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
# (ClientAppActor pid=56989)   parse = parser.parseString(pattern)
# (ClientAppActor pid=56989) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
# (ClientAppActor pid=56989)   parser.resetCache()
# (ClientAppActor pid=56989) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_mathtext.py:45: PyparsingDeprecationWarning: 'enablePackrat' deprecated - use 'enable_packrat'
# (ClientAppActor pid=56989)   ParserElement.enablePackrat()
# (ClientAppActor pid=56989) In /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'parseString' deprecated - use 'parse_string'
# (ClientAppActor pid=56989) In /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'resetCache' deprecated - use 'reset_cache'
# INFO : aggregate_fit: received 2 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0054 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=56986) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
# (ClientAppActor pid=56986)   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# (ClientAppActor pid=56986) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
# (ClientAppActor pid=56986)   parse = parser.parseString(pattern)
# (ClientAppActor pid=56986) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
# (ClientAppActor pid=56986)   parser.resetCache()
# (ClientAppActor pid=56986) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_mathtext.py:45: PyparsingDeprecationWarning: 'enablePackrat' deprecated - use 'enable_packrat'
# (ClientAppActor pid=56986)   ParserElement.enablePackrat()
# (ClientAppActor pid=56986) In /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'parseString' deprecated - use 'parse_string'
# (ClientAppActor pid=56986) In /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'resetCache' deprecated - use 'reset_cache'
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 2]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=56982) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0935. [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (ClientAppActor pid=56978) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of' [repeated 5x across cluster]
# (ClientAppActor pid=56978)   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS)) [repeated 5x across cluster]
# (ClientAppActor pid=56978) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string' [repeated 5x across cluster]
# (ClientAppActor pid=56978)   parse = parser.parseString(pattern) [repeated 5x across cluster]
# (ClientAppActor pid=56978) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache' [repeated 5x across cluster]
# (ClientAppActor pid=56978)   parser.resetCache() [repeated 5x across cluster]
# (ClientAppActor pid=56978) /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/_mathtext.py:45: PyparsingDeprecationWarning: 'enablePackrat' deprecated - use 'enable_packrat' [repeated 5x across cluster]
# (ClientAppActor pid=56978)   ParserElement.enablePackrat() [repeated 5x across cluster]
# (ClientAppActor pid=56978) In /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'parseString' deprecated - use 'parse_string' [repeated 5x across cluster]
# (ClientAppActor pid=56978) In /home/ubuntu/fl-workshop/federated-learning-with-flower/.venv/lib/python3.12/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'resetCache' deprecated - use 'reset_cache' [repeated 5x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0048 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 3]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=56987) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0840. [repeated 6x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0045 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 4]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=56986) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0778. [repeated 6x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0040 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [ROUND 5]
# INFO : configure_fit: strategy sampled 6 clients (out of 10)
# (ClientAppActor pid=56990) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0699. [repeated 6x across cluster]
# INFO : aggregate_fit: received 6 results and 0 failures
# INFO : aggregate_fit: central DP noise with 0.0037 stdev added
# INFO : configure_evaluate: strategy sampled 10 clients (out of 10)
# INFO : aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO : [SUMMARY]
# INFO : Run finished 5 round(s) in 59.17s
# INFO : 	History (loss, distributed):
# INFO : 		round 1: 42.49201810359955
# INFO : 		round 2: 41.317304849624634
# INFO : 		round 3: 40.21774492263794
# INFO : 		round 4: 39.15343554019928
# INFO : 		round 5: 38.339125108718875
# INFO :
# (ClientAppActor pid=56980) INFO : adaptiveclipping_mod: parameters are clipped by value: 0.0699. [repeated 5x across cluster]
